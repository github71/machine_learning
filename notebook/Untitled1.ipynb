# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Load the sample data

# %%
df = pd.read_csv('./notebook_data/notebook1_data.txt')
df1 = df[df['category'] == 'red']
df2 = df[df['category'] == 'blue']
plt.scatter(df2.x,df2.y,color='blue')
plt.scatter(df1.x,df1.y,color='red')
